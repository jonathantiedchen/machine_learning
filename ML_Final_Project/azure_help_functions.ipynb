# %%
from azure.storage.blob import BlobServiceClient
import json
import os
from PIL import Image
import matplotlib.pyplot as plt
import io  # Used to convert bytes to a file-like object


#set up storage
connection_string = "DefaultEndpointsProtocol=https;AccountName=mlfinalexam5505462853;AccountKey=0c40lghglG5/GlNK9yujDQAgo38GKoS2I3DeC/g22hwAEIFANKpmC/TqOpRk4RCT1DbfNiHBFt72+AStB+PfUA==;EndpointSuffix=core.windows.net"
container_name = "publicdata"

#create client
blob_service_client = BlobServiceClient.from_connection_string(connection_string)
container_client = blob_service_client.get_container_client(container_name)

# %% [markdown]
# ### Plotting an Image

# %%
##### Plot plain image function

# Directory where your JPEG files are located
def plot_image(image_id):
    # Get the BlobClient for the specific image
    blob_client = container_client.get_blob_client(image_id)

    # Download the blob's content as bytes
    blob_data = blob_client.download_blob().chunks()  # Read the entire blob content

    # Convert the blob data into a file-like object using io.BytesIO
    image_data = io.BytesIO(b"".join(blob_data))

    # Open the image using PIL.Image
    image = Image.open(image_data)

    # Display the image using matplotlib
    plt.imshow(image)
    plt.axis('off')  # Hide axes for better visualization
    plt.title(f"Image with ID {image_id}")
    plt.show()

# %%
image = "resized_samples/CAM_BACK_LEFT/n013-2018-08-03-14-44-49+0800__CAM_BACK_LEFT__1533278795447155.jpg"
plot_image(image)

# %% [markdown]
# ### Resize Images

# %%
# Function to downscale and re-upload the image to a new path
def downscale_and_reupload(image_blob_name):
    # Download the original image
    blob_client = container_client.get_blob_client(image_blob_name)
    blob_data = blob_client.download_blob().readall()

    # Open the image using Pillow
    image_data = io.BytesIO(blob_data)
    image = Image.open(image_data)

    # Downscale the image
    #new_width = image.width // downscale_factor
    #new_height = image.height // downscale_factor
    downscaled_image = image.resize((256, 256), Image.Resampling.LANCZOS)

    # Save the downscaled image to a file-like object
    output_stream = io.BytesIO()
    downscaled_image.save(output_stream, format='JPEG')
    output_stream.seek(0)  # Reset the stream position to the beginning

    # Create a new blob name with the desired path
    new_blob_name = image_blob_name.replace("samples", "resized_samples")

    # Re-upload the downscaled image to the new path
    new_blob_client = container_client.get_blob_client(new_blob_name)
    new_blob_client.upload_blob(output_stream, overwrite=True)  # Overwrite if it exists

    return new_blob_name  # Return the name of the re-uploaded image

blobs = container_client.list_blobs()
for blob in blobs:
    if blob.name.endswith(".jpg"):
        image_blob_name = blob.name
        downscaled_image_blob_name= downscale_and_reupload(image_blob_name)
        print(f"Downscaled image re-uploaded as: {downscaled_image_blob_name}")
# Out:
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n003-2018-01-03-12-03-23+0800__CAM_BACK__1514952316316487.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n003-2018-01-08-11-30-34+0800__CAM_BACK__1515382745757583.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n003-2018-07-12-15-40-35+0800__CAM_BACK__1531383596387543.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n005-2018-06-14-20-11-03+0800__CAM_BACK__1528979868187591.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n008-2018-06-04-16-30-00-0400__CAM_BACK__1528144232887570.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n009-2018-05-08-15-52-41-0400__CAM_BACK__1525809758643363.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n010-2018-08-27-12-00-23+0800__CAM_BACK__1535342963787283.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n013-2018-08-20-14-38-24+0800__CAM_BACK__1534747168787005.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n013-2018-08-21-11-46-25+0800__CAM_BACK__1534823329537005.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n013-2018-08-28-16-04-27+0800__CAM_BACK__1535443725287005.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK/n013-2018-08-29-11-41-15+0800__CAM_BACK__1535514187537005.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_LEFT/n008-2018-05-30-16-31-36-0400__CAM_BACK_LEFT__1527712679297295.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_LEFT/n010-2018-07-05-14-36-33+0800__CAM_BACK_LEFT__1530772754897633.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_LEFT/n010-2018-07-06-11-01-46+0800__CAM_BACK_LEFT__1530847097147633.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_LEFT/n010-2018-08-27-15-10-53+0800__CAM_BACK_LEFT__1535354198047633.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_LEFT/n013-2018-08-02-14-08-14+0800__CAM_BACK_LEFT__1533190807197155.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_LEFT/n013-2018-08-03-14-44-49+0800__CAM_BACK_LEFT__1533278795447155.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_LEFT/n013-2018-08-16-16-15-38+0800__CAM_BACK_LEFT__1534407626447155.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_LEFT/n013-2018-08-27-16-40-42+0800__CAM_BACK_LEFT__1535359525897155.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_LEFT/n015-2018-09-19-11-19-35+0800__CAM_BACK_LEFT__1537327456197423.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_LEFT/n016-2018-07-10-16-55-57+0800__CAM_BACK_LEFT__1531214187897243.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_RIGHT/n003-2018-01-04-11-23-25+0800__CAM_BACK_RIGHT__1515036641194368.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_RIGHT/n008-2018-05-21-11-06-59-0400__CAM_BACK_RIGHT__1526915734627813.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_RIGHT/n008-2018-05-30-15-20-59-0400__CAM_BACK_RIGHT__1527708173277813.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_RIGHT/n008-2018-05-30-16-31-36-0400__CAM_BACK_RIGHT__1527713376627813.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_RIGHT/n013-2018-08-02-13-54-05+0800__CAM_BACK_RIGHT__1533189734678054.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_RIGHT/n013-2018-08-27-11-35-10+0800__CAM_BACK_RIGHT__1535341306278054.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_RIGHT/n014-2018-06-25-21-03-46-0400__CAM_BACK_RIGHT__1529975550278469.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_RIGHT/n015-2018-09-13-15-25-57+0800__CAM_BACK_RIGHT__1536824126277893.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_BACK_RIGHT/n016-2018-07-06-12-06-18+0800__CAM_BACK_RIGHT__1530850955877917.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT/n006-2018-09-17-12-15-45-0400__CAM_FRONT__1537201092012482.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT/n008-2018-03-14-15-16-29-0400__CAM_FRONT__1521055565282267.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT/n008-2018-05-21-11-06-59-0400__CAM_FRONT__1526915374762465.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT/n008-2018-09-18-14-18-33-0400__CAM_FRONT__1537294833612404.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT/n009-2018-09-12-09-59-51-0400__CAM_FRONT__1536761961012656.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT/n013-2018-08-01-16-46-39+0800__CAM_FRONT__1533113758512407.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT/n013-2018-08-20-14-38-24+0800__CAM_FRONT__1534747862612407.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT/n016-2018-07-04-10-44-39+0800__CAM_FRONT__1530672741162515.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_LEFT/n010-2018-09-17-15-57-10+0800__CAM_FRONT_LEFT__1537171282504509.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_LEFT/n013-2018-08-16-16-15-38+0800__CAM_FRONT_LEFT__1534408311904825.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_LEFT/n013-2018-08-29-14-19-16+0800__CAM_FRONT_LEFT__1535524658904825.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_LEFT/n013-2018-09-03-14-54-42+0800__CAM_FRONT_LEFT__1535958018154825.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_LEFT/n013-2018-09-04-13-30-50+0800__CAM_FRONT_LEFT__1536039168104825.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_RIGHT/n004-2018-01-04-11-05-42+0800__CAM_FRONT_RIGHT__1515035386214952.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_RIGHT/n005-2018-06-14-20-11-03+0800__CAM_FRONT_RIGHT__1528978813270418.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_RIGHT/n008-2018-05-21-11-06-59-0400__CAM_FRONT_RIGHT__1526915251619956.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_RIGHT/n013-2018-08-27-14-41-26+0800__CAM_FRONT_RIGHT__1535352274870176.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_RIGHT/n013-2018-08-27-15-47-08+0800__CAM_FRONT_RIGHT__1535356254370176.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_RIGHT/n015-2018-09-05-12-12-46+0800__CAM_FRONT_RIGHT__1536121409120339.jpg
# Downscaled image re-uploaded as: resized_samples/CAM_FRONT_RIGHT/n016-2018-07-10-11-22-35+0800__CAM_FRONT_RIGHT__1531193197170471.jpg

# %%
# Example image to process
image_blob_name = "samples/CAM_BACK_LEFT/n013-2018-08-03-14-44-49+0800__CAM_BACK_LEFT__1533278795447155.jpg"

# Downscale the image and re-upload to a new path
downscaled_image_blob_name = downscale_and_reupload(image_blob_name, 5)

print(f"Downscaled image re-uploaded as: {downscaled_image_blob_name}")
# Out:
# Downscaled image re-uploaded as: processed_samples/CAM_BACK_LEFT/n013-2018-08-03-14-44-49+0800__CAM_BACK_LEFT__1533278795447155.jpg

# %% [markdown]
# ### Delete files in Azure

# %%
### delete files in azure
# Specify the folder prefix (e.g., "samples/")
folder_prefixes = ["processed_samples/CAM_BACK/","processed_samples/CAM_BACK_LEFT/","processed_samples/CAM_BACK_RIGHT/",
                 "processed_samples/CAM_FRONT/","processed_samples/CAM_FRONT_LEFT/","processed_samples/CAM_FRONT_RIGHT/"]

folder_prefix="processed_samples/CAM_FRONT_RIGHT/"
# List all blobs in the folder
blobs = container_client.list_blobs(name_starts_with=folder_prefix)

# Delete each blob in the folder
for blob in blobs:
    blob_client = container_client.get_blob_client(blob.name)
    blob_client.delete_blob()
    print(f"Deleted blob: {blob.name}")
# Out:
# Deleted blob: processed_samples/CAM_FRONT_RIGHT/n004-2018-01-04-11-05-42+0800__CAM_FRONT_RIGHT__1515035386214952.jpg
# Deleted blob: processed_samples/CAM_FRONT_RIGHT/n005-2018-06-14-20-11-03+0800__CAM_FRONT_RIGHT__1528978813270418.jpg
# Deleted blob: processed_samples/CAM_FRONT_RIGHT/n008-2018-05-21-11-06-59-0400__CAM_FRONT_RIGHT__1526915251619956.jpg
# Deleted blob: processed_samples/CAM_FRONT_RIGHT/n013-2018-08-27-14-41-26+0800__CAM_FRONT_RIGHT__1535352274870176.jpg
# Deleted blob: processed_samples/CAM_FRONT_RIGHT/n013-2018-08-27-15-47-08+0800__CAM_FRONT_RIGHT__1535356254370176.jpg
# Deleted blob: processed_samples/CAM_FRONT_RIGHT/n015-2018-09-05-12-12-46+0800__CAM_FRONT_RIGHT__1536121409120339.jpg
# Deleted blob: processed_samples/CAM_FRONT_RIGHT/n016-2018-07-10-11-22-35+0800__CAM_FRONT_RIGHT__1531193197170471.jpg

# %% [markdown]
# ### Count Files in Azure Folder

# %%
#check number ob blobs in folder

container_name = "datacomplete"  # Your Azure Blob Storage container
container_client = blob_service_client.get_container_client(container_name)


folders=['CAM_BACK','CAM_BACK_LEFT','CAM_BACK_RIGHT','CAM_FRONT','CAM_FRONT_LEFT','CAM_FRONT_RIGHT']
# Specify the folder prefix (e.g., "samples/")
prefix = "samples/"
for folder in folders: 
    # List all blobs in the container
    folder_prefix=f"{prefix}{folder}/"
    blobs = container_client.list_blobs(name_starts_with=folder_prefix)

    # Count the blobs that start with the specified folder prefix
    blob_count = sum(1 for _ in blobs)  # Generator comprehension to count blobs

    print(f"Number of blobs in '{folder_prefix}': {blob_count}")
# Out:
# Number of blobs in 'samples/CAM_BACK/': 17105
# Number of blobs in 'samples/CAM_BACK_LEFT/': 14882
# Number of blobs in 'samples/CAM_BACK_RIGHT/': 13341
# Number of blobs in 'samples/CAM_FRONT/': 18368
# Number of blobs in 'samples/CAM_FRONT_LEFT/': 15167
# Number of blobs in 'samples/CAM_FRONT_RIGHT/': 14613
